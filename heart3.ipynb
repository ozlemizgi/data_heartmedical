# %% [markdown]
# <a href="https://colab.research.google.com/github/ozlemizgi/data_heartmedical/blob/main/heart3.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# Kütüphanelerin çağırılması
import pandas as pd

# %%
# Eğer veri dosyası başka bir klasörün içindeyse Klasörün adını da belirtmemiz gerekiyor.
heart = pd.read_csv("https://raw.githubusercontent.com/ozlemizgi/data_heartmedical/main/csv_result-Medicaldataset.csv")
heart
# Out:
#         id  age  gender  impluse  pressurehight  pressurelow  glucose    kcm  \
# 0        1   64       1       66            160           83    160.0   1.80
# 1        2   21       1       94             98           46    296.0   6.75
# 2        3   55       1       64            160           77    270.0   1.99
# 3        4   64       1       70            120           55    270.0  13.87
# 4        5   55       1       64            112           65    300.0   1.08
# ...    ...  ...     ...      ...            ...          ...      ...    ...
# 1314  1315   44       1       94            122           67    204.0   1.63
# 1315  1316   66       1       84            125           55    149.0   1.33
# 1316  1317   45       1       85            168          104     96.0   1.24
# 1317  1318   54       1       58            117           68    443.0   5.80
# 1318  1319   51       1       94            157           79    134.0  50.89
#
#       troponin     class
# 0        0.012  negative
# 1        1.060  positive
# 2        0.003  negative
# 3        0.122  positive
# 4        0.003  negative
# ...        ...       ...
# 1314     0.006  negative
# 1315     0.172  positive
# 1316     4.250  positive
# 1317     0.359  positive
# 1318     1.770  positive
#
# [1319 rows x 10 columns]

# %%
## head(x): veri setindeki ilk x adet veriyi gösterir.

heart.head(3)
# Out:
#    id  age  gender  impluse  pressurehight  pressurelow  glucose   kcm  \
# 0   1   64       1       66            160           83    160.0  1.80
# 1   2   21       1       94             98           46    296.0  6.75
# 2   3   55       1       64            160           77    270.0  1.99
#
#    troponin     class
# 0     0.012  negative
# 1     1.060  positive
# 2     0.003  negative

# %%
## tail(x): veri setindeki son x adet veriyi gösterir.

heart.tail(6)
# Out:
#         id  age  gender  impluse  pressurehight  pressurelow  glucose    kcm  \
# 1313  1314   86       0       40            179           68    147.0   5.22
# 1314  1315   44       1       94            122           67    204.0   1.63
# 1315  1316   66       1       84            125           55    149.0   1.33
# 1316  1317   45       1       85            168          104     96.0   1.24
# 1317  1318   54       1       58            117           68    443.0   5.80
# 1318  1319   51       1       94            157           79    134.0  50.89
#
#       troponin     class
# 1313     0.011  negative
# 1314     0.006  negative
# 1315     0.172  positive
# 1316     4.250  positive
# 1317     0.359  positive
# 1318     1.770  positive

# %%
## sample(x): veri setinden rasgele olarak x adet veriyi örnekler.

heart.sample(9)
# Out:
#         id  age  gender  impluse  pressurehight  pressurelow  glucose     kcm  \
# 886    887   35       1       70            117           76    111.0    2.16
# 69      70   46       1       78            115           65    123.0    4.45
# 729    730   53       1       66             94           63    202.0    2.84
# 676    677   75       0       81            118           66     88.0    4.55
# 185    186   66       1       69            129           73    215.0  300.00
# 501    502   59       0       62             76           55    130.0    2.21
# 1188  1189   29       1       84             87           48    104.0    1.58
# 532    533   53       1       51            118           50     60.0    1.78
# 265    266   63       1       67            120           64     94.0    2.72
#
#       troponin     class
# 886      0.003  negative
# 69       0.007  negative
# 729      0.003  negative
# 676      0.010  negative
# 185      0.005  positive
# 501      0.145  positive
# 1188     0.003  negative
# 532      0.007  negative
# 265      0.245  positive

# %%
# shape: verinin boyutlarını gösterir. (x:satır, y:sütun)
heart.shape
# Out:
# (1319, 10)

# %%
# columns: sütun isimlerini verir.
heart.columns
# Out:
# Index(['id', 'age', 'gender', 'impluse', 'pressurehight', 'pressurelow',
#        'glucose', 'kcm', 'troponin', 'class'],
#       dtype='object')

# %%
# info():  veri hakkında genel bilgi verir. 
# (Kaç sütun olduğu, sütun isimleri, her sütunda kaç örnek olduğu, eksik örnek olup olmadığı ve veri tipleri)
heart.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1319 entries, 0 to 1318
# Data columns (total 10 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   id             1319 non-null   int64
#  1   age            1319 non-null   int64
#  2   gender         1319 non-null   int64
#  3   impluse        1319 non-null   int64
#  4   pressurehight  1319 non-null   int64
#  5   pressurelow    1319 non-null   int64
#  6   glucose        1319 non-null   float64
#  7   kcm            1319 non-null   float64
#  8   troponin       1319 non-null   float64
#  9   class          1319 non-null   object
# dtypes: float64(3), int64(6), object(1)
# memory usage: 103.2+ KB

# %%
# describe():  verinin istatistiksel bir özetini sunar.
# Count: örnek sayısı, mean: ortalama, std: standart sapma, min: minimim değer
# 25%: Q1, %50: Q2 veya median, 75%: Q3, max: maksimum değer

heart.describe()
# Out:
#                 id          age       gender      impluse  pressurehight  \
# count  1319.000000  1319.000000  1319.000000  1319.000000    1319.000000
# mean    660.000000    56.191812     0.659591    78.336619     127.170584
# std     380.906813    13.647315     0.474027    51.630270      26.122720
# min       1.000000    14.000000     0.000000    20.000000      42.000000
# 25%     330.500000    47.000000     0.000000    64.000000     110.000000
# 50%     660.000000    58.000000     1.000000    74.000000     124.000000
# 75%     989.500000    65.000000     1.000000    85.000000     143.000000
# max    1319.000000   103.000000     1.000000  1111.000000     223.000000
#
#        pressurelow      glucose          kcm     troponin
# count  1319.000000  1319.000000  1319.000000  1319.000000
# mean     72.269143   146.634344    15.274306     0.360942
# std      14.033924    74.923045    46.327083     1.154568
# min      38.000000    35.000000     0.321000     0.001000
# 25%      62.000000    98.000000     1.655000     0.006000
# 50%      72.000000   116.000000     2.850000     0.014000
# 75%      81.000000   169.500000     5.805000     0.085500
# max     154.000000   541.000000   300.000000    10.300000

# %%
from IPython.display import Image

# Box Plot grafiği
Image("Image/boxplot.png")

# %%
# Normal Dağılım
Image("Image/normal_distribution.png")

# %%
# UCI Machine Learning Repository
Image("Image/UCI.png")

# %%
# value_counts(): bir özellikteki string veya kategorik verilerin sayısını belirler.
heart["class"].value_counts()
# Out:
# positive    810
# negative    509
# Name: class, dtype: int64

# %%
# value_counts(): bir özellikteki string veya kategorik verilerin sayısını belirler.
heart["age"].value_counts()
# Out:
# 60     106
# 70      73
# 50      68
# 63      64
# 65      62
#       ...
# 88       1
# 100      1
# 14       1
# 91       1
# 84       1
# Name: age, Length: 75, dtype: int64

# %%
# value_counts(): bir özellikteki string veya kategorik verilerin sayısını belirler.
heart["gender"].value_counts()
# Out:
# 1    870
# 0    449
# Name: gender, dtype: int64

# %%
## For Döngüsü ile Tüm sütunların değerlerini ve sayılarını yazdırma
for i in (heart.columns):
    print(i)
    print(heart[i].value_counts())
    print("\n")
# Out:
# id
# 1       1
# 887     1
# 885     1
# 884     1
# 883     1
#        ..
# 440     1
# 439     1
# 438     1
# 437     1
# 1319    1
# Name: id, Length: 1319, dtype: int64
#
#
# age
# 60     106
# 70      73
# 50      68
# 63      64
# 65      62
#       ...
# 88       1
# 100      1
# 14       1
# 91       1
# 84       1
# Name: age, Length: 75, dtype: int64
#
#
# gender
# 1    870
# 0    449
# Name: gender, dtype: int64
#
#
# impluse
# 60     95
# 61     57
# 70     48
# 64     47
# 82     46
#        ..
# 49      1
# 46      1
# 110     1
# 36      1
# 45      1
# Name: impluse, Length: 79, dtype: int64
#
#
# pressurehight
# 150    50
# 130    41
# 125    41
# 120    38
# 140    32
#        ..
# 204     1
# 78      1
# 71      1
# 70      1
# 89      1
# Name: pressurehight, Length: 116, dtype: int64
#
#
# pressurelow
# 75     69
# 68     67
# 80     57
# 70     44
# 60     43
#        ..
# 102     1
# 106     1
# 38      1
# 47      1
# 154     1
# Name: pressurelow, Length: 73, dtype: int64
#
#
# glucose
# 100.0    41
# 87.0     32
# 98.0     31
# 96.0     30
# 94.0     30
#          ..
# 338.0     1
# 282.0     1
# 354.0     1
# 153.0     1
# 331.0     1
# Name: glucose, Length: 244, dtype: int64
#
#
# kcm
# 300.000    19
# 1.600      11
# 2.110       9
# 1.330       9
# 1.830       9
#            ..
# 0.657       1
# 3.420       1
# 3.490       1
# 5.730       1
# 4.010       1
# Name: kcm, Length: 700, dtype: int64
#
#
# troponin
# 0.003    190
# 0.006     67
# 0.005     65
# 0.004     64
# 0.007     54
#         ...
# 2.340      1
# 0.697      1
# 0.853      1
# 1.060      1
# 1.770      1
# Name: troponin, Length: 352, dtype: int64
#
#
# class
# positive    810
# negative    509
# Name: class, dtype: int64

# %%
# Mendeley Data
Image("Image/mendeley_data.png")
